# %% [markdown]
# <a href="https://colab.research.google.com/github/larialbu/Calculadora-em-js/blob/main/aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('olá mundo')
# Out:
# olá mundo

# %%
nome = 'larissa' ; idade=17

# %%
print('ola', nome)
# Out:
# ola larissa

# %%
pessoa = 'larissa' ; idade = 17 ; altura = 1.55 ; desenvolvedora = True

# %%
type(pessoa)
# Out:
# str

# %%
type(idade)
# Out:
# int

# %%
type(altura)
# Out:
# float

# %%
type(desenvolvedora)
# Out:
# bool

# %%
pessoa = 1234

# %%
print(pessoa)
# Out:
# 1234

# %%
type(pessoa)
# Out:
# str

# %%
print('olá', nome) #podemos comentar assim
# Out:
# olá larissa

# %%
print('olá', nome)

"""podemos fazer comentarios em 
varias linhas usando aspas"""
# Out:
# olá larissa
# 'podemos fazer comentarios em \nvarias linhas usando aspas'
